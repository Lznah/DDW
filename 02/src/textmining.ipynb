# %%
import nltk
import pandas
import unicodedata

# %% [markdown]
# ## Read and transform data
#
# Read data and replace utf-8 specific symbols from the text. From that, select some number of sentences.

# %%
df = pandas.read_csv('news.csv')

# %%
sentences = unicodedata.normalize("NFKD", " ".join(df['text'][0:12]) ) # 0:12 - exactly 500 sentences

# %% [markdown]
# ## Sentences
#
# Let's check, if the sentences selection fulfill the requirement of the task, that it contains at least 500 sentences.

# %%
sentences_tokens = nltk.sent_tokenize(sentences)

print("Length:"+str(len(sentences_tokens)))
# Out:
# Length:500

# %% [markdown]
# ## Import from tutorial
# The following code is from tutorial 3.

# %%
# ExctractEntities    
def extract_entities(ne_chunked):
    data = {}
    for entity in ne_chunked:
        if isinstance(entity, nltk.tree.Tree):
            text = " ".join([word for word, tag in entity.leaves()])
            ent = entity.label()
            data[text] = ent
        else:
            continue
    return data

# %% [markdown]
# ## POS TAG
# Also known as Part-of-Speech tagging is a process of marking words to corresponding parts of speech in a given sentence.

# %%
tokens = nltk.word_tokenize(sentences)
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('Canadian', 'JJ'),
#  ('pharmacies', 'NNS'),
#  ('are', 'VBP'),
#  ('limiting', 'VBG'),
#  ('how', 'WRB'),
#  ('much', 'JJ'),
#  ('medication', 'NN'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('dispensed', 'VBN'),
#  ('to', 'TO'),
#  ('try', 'VB'),
#  ('to', 'TO'),
#  ('prevent', 'VB'),
#  ('shortages', 'NNS'),
#  (',', ','),
#  ('recognizing', 'VBG'),
#  ('that', 'IN'),
#  ('most', 'JJS'),
#  ('active', 'JJ'),
#  ('ingredients', 'NNS'),
#  ('for', 'IN'),
#  ('drugs', 'NNS'),
#  ('come', 'VBP'),
#  ('from', 'IN'),
#  ('India', 'NNP'),
#  ('and', 'CC'),
#  ('China', 'NNP'),
#  ('and', 'CC'),
#  ('medical', 'JJ'),
#  ('supply', 'NN'),
#  ('chains', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('disrupted', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('spread', 'NN'),
#  ('of', 'IN'),
#  ('COVID-19', 'NNP'),
#  ('.', '.'),
#  ('Provincial', 'NNP'),
#  ('regulatory', 'JJ'),
#  ('colleges', 'NNS'),
#  ('are', 'VBP'),
#  ('complying', 'VBG'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Canadian', 'NNP'),
#  ('Pharmacists', 'NNP'),
#  ('Association', 'NNP'),
#  ('call', 'NN'),
#  ('to', 'TO'),
#  ('limit', 'VB'),
#  ('the', 'DT'),
#  ('amount', 'NN'),
#  ('of', 'IN'),
#  ('medications', 'NNS'),
#  ('given', 'VBN'),
#  ('to', 'TO'),
#  ('patients', 'NNS'),
#  ('to', 'TO'),
#  ('30-day', 'JJ'),
#  ('supplies', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('goal', 'NN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('stop', 'VB'),
#  ('people', 'NNS'),
#  ('from', 'IN'),
#  ('refilling', 'VBG'),
#  ('prescriptions', 'NNS'),
#  ('early', 'RB'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('ensure', 'VB'),
#  ('life-saving', 'JJ'),
#  ('drugs', 'NNS'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('run', 'VB'),
#  ('short', 'RB'),
#  ('when', 'WRB'),
#  ('supply', 'NN'),
#  ('chains', 'NNS'),
#  ('are', 'VBP'),
#  ('vulnerable', 'JJ'),
#  ('.', '.'),
#  ('Mina', 'NNP'),
#  ('Tadrous', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('pharmacist', 'NN'),
#  ('and', 'CC'),
#  ('researcher', 'NN'),
#  ('in', 'IN'),
#  ('Toronto', 'NNP'),
#  ('who', 'WP'),
#  ('monitors', 'VBZ'),
#  ('pharmaceutical', 'JJ'),
#  ('supplies', 'NNS'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('worried', 'JJ'),
#  ('Canadians', 'NNPS'),
#  ('will', 'MD'),
#  ('start', 'VB'),
#  ('stockpiling', 'VBG'),
#  ('drugs', 'NNS'),
#  ('after', 'IN'),
#  ('watching', 'VBG'),
#  ('what', 'WDT'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('unfolding', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('U.S.', 'NNP'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('regions', 'NNS'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('virus', 'NN'),
#  ('spreads', 'NNS'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  ('pharmacists', 'NNS'),
#  ('are', 'VBP'),
#  ('concerned', 'VBN'),
#  ('about', 'IN'),
#  ('drugs', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('life-saving', 'JJ'),
#  ('inhalers', 'NNS'),
#  ('that', 'WDT'),
#  ('people', 'NNS'),
#  ('might', 'MD'),
#  ('stockpile', 'VB'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('misinformation', 'NN'),
#  ('circulating', 'VBG'),
#  ('about', 'IN'),
#  ('potential', 'JJ'),
#  ('treatments', 'NNS'),
#  ('for', 'IN'),
#  ('COVID-19', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('that', 'IN'),
#  ('relationship', 'NN'),
#  ('of', 'IN'),
#  ('how', 'WRB'),
#  ('people', 'NNS'),
#  ('are', 'VBP'),
#  ('reacting', 'VBG'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('actual', 'JJ'),
#  ('supply', 'NN'),
#  ('of', 'IN'),
#  ('medications', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('Tadrous', 'NNP'),
#  ('said', 'VBD'),
#  ('pharmacies', 'NNS'),
#  ('get', 'VBP'),
#  ('their', 'PRP$'),
#  ('medications', 'NNS'),
#  ('and', 'CC'),
#  ('supplies', 'NNS'),
#  ('from', 'IN'),
#  ('wholesalers', 'NNS'),
#  (',', ','),
#  ('who', 'WP'),
#  ('get', 'VBP'),
#  ('theirs', 'PRP'),
#  ('from', 'IN'),
#  ('distributors', 'NNS'),
#  ('who', 'WP'),
#  ('source', 'NN'),
#  ('them', 'PRP'),
#  ('from', 'IN'),
#  ('manufacturers', 'NNS'),
#  ('.', '.'),
#  ('Outside', 'IN'),
#  ('of', 'IN'),
#  ('wholesalers', 'NNS'),
#  (',', ','),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('that', 'DT'),
#  ('supply', 'NN'),
#  ('chain', 'NN'),
#  ('is', 'VBZ'),
#  ('outside', 'IN'),
#  ('of', 'IN'),
#  ('Canada', 'NNP'),
#  ('.', '.'),
#  ('Ongoing', 'NNP'),
#  ('shortages', 'NNS'),
#  ('Dr.', 'NNP'),
#  ('Jacalyn', 'NNP'),
#  ('Duffin', 'NNP'),
#  ('of', 'IN'),
#  ('Queen', 'NNP'),
#  ("'s", 'POS'),
#  ('University', 'NNP'),
#  ('in', 'IN'),
#  ('Kingston', 'NNP'),
#  (',', ','),
#  ('Ont.', 'NNP'),
#  (',', ','),
#  ('has', 'VBZ'),
#  ('long', 'RB'),
#  ('warned', 'VBN'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('increasing', 'VBG'),
#  ('frequency', 'NN'),
#  ('of', 'IN'),
#  ('drug', 'NN'),
#  ('shortages', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('nearly', 'RB'),
#  ('2,000', 'CD'),
#  ('ongoing', 'JJ'),
#  ('shortages', 'NNS'),
#  (',', ','),
#  ('none', 'NN'),
#  ('of', 'IN'),
#  ('which', 'WDT'),
#  ('she', 'PRP'),
#  ('attributes', 'VBZ'),
#  ('to', 'TO'),
#  ('coronavirus', 'VB'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  ('and', 'CC'),
#  ('India', 'NNP'),
#  ('produce', 'VBP'),
#  ('80', 'CD'),
#  ('per', 'IN'),
#  ('cent', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('active', 'JJ'),
#  ('ingredients', 'NNS'),
#  ('of', 'IN'),
#  ('prescription', 'NN'),
#  ('drugs', 'NNS'),
#  ('sold', 'VBN'),
#  ('in', 'IN'),
#  ('North', 'NNP'),
#  ('America', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('Dr.', 'NNP'),
#  ('Jacalyn', 'NNP'),
#  ('Duffin', 'NNP'),
#  ('.', '.'),
#  ('(', '('),
#  ('Kas', 'NNP'),
#  ('Roussy/CBC', 'NNP'),
#  (')', ')'),
#  ('Given', 'VBZ'),
#  ('that', 'IN'),
#  ('China', 'NNP'),
#  ('and', 'CC'),
#  ('India', 'NNP'),
#  ('produce', 'VBP'),
#  ('80', 'CD'),
#  ('per', 'IN'),
#  ('cent', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('active', 'JJ'),
#  ('ingredients', 'NNS'),
#  ('of', 'IN'),
#  ('prescription', 'NN'),
#  ('drugs', 'NNS'),
#  ('sold', 'VBN'),
#  ('in', 'IN'),
#  ('North', 'NNP'),
#  ('America', 'NNP'),
#  (',', ','),
#  ('supply', 'NN'),
#  ('disruptions', 'NNS'),
#  ('are', 'VBP'),
#  ('expected', 'VBN'),
#  ('eventually', 'RB'),
#  (',', ','),
#  ('Duffin', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('coronavirus', 'NN'),
#  ('outbreak', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('big', 'JJ'),
#  ('wake-up', 'NN'),
#  ('call', 'NN'),
#  ('for', 'IN'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('pay', 'VB'),
#  ('attention', 'NN'),
#  ('to', 'TO'),
#  ('our', 'PRP$'),
#  ('drug', 'NN'),
#  ('shortages', 'VBZ'),
#  ('that', 'IN'),
#  ('exist', 'VBP'),
#  ('already', 'RB'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('pay', 'VB'),
#  ('attention', 'NN'),
#  ('to', 'TO'),
#  ('where', 'WRB'),
#  ('our', 'PRP$'),
#  ('drugs', 'NNS'),
#  ('come', 'VBP'),
#  ('from', 'IN'),
#  (',', ','),
#  ("''", "''"),
#  ('she', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('What', 'WP'),
#  ('you', 'PRP'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('about', 'IN'),
#  ('getting', 'VBG'),
#  ('new', 'JJ'),
#  ('prescriptions', 'NNS'),
#  (',', ','),
#  ('refillsNew', 'NN'),
#  ('Brunswick', 'NNP'),
#  ('offers', 'VBZ'),
#  ('relief', 'NN'),
#  ('on', 'IN'),
#  ('prescription', 'NN'),
#  ('co-pays', 'NNS'),
#  ('during', 'IN'),
#  ('outbreak', 'JJ'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('supplier', 'NN'),
#  ('of', 'IN'),
#  ('generic', 'JJ'),
#  ('drugs', 'NNS'),
#  ('to', 'TO'),
#  ('Europe', 'NNP'),
#  (',', ','),
#  ('has', 'VBZ'),
#  ('already', 'RB'),
#  ('shut', 'VBN'),
#  ('down', 'RP'),
#  ('the', 'DT'),
#  ('export', 'NN'),
#  ('of', 'IN'),
#  ('some', 'DT'),
#  ('antibiotics', 'NNS'),
#  ('and', 'CC'),
#  ('drugs', 'NNS'),
#  ('for', 'IN'),
#  ('hypertension', 'NN'),
#  (',', ','),
#  ('blood', 'NN'),
#  ('pressure', 'NN'),
#  ('and', 'CC'),
#  ('acetaminophen', 'NN'),
#  (',', ','),
#  ('Duffin', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('a', 'DT'),
#  ('precaution', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('federal', 'JJ'),
#  ('government', 'NN'),
#  ('has', 'VBZ'),
#  ('enacted', 'VBN'),
#  ('sweeping', 'JJ'),
#  ('legislation', 'NN'),
#  ('that', 'WDT'),
#  ('gives', 'VBZ'),
#  ('it', 'PRP'),
#  ('the', 'DT'),
#  ('right', 'NN'),
#  ('to', 'TO'),
#  ('force', 'VB'),
#  ('patented', 'JJ'),
#  ('drugmakers', 'NNS'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('more', 'JJR'),
#  ('medicine', 'NN'),
#  ('if', 'IN'),
#  ('necessary', 'JJ'),
#  ('and', 'CC'),
#  ('remove', 'VB'),
#  ('patents', 'NNS'),
#  ('as', 'IN'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('response', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('public', 'JJ'),
#  ('health', 'NN'),
#  ('emergency', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Yukon', 'JJ'),
#  ('government', 'NN'),
#  ('has', 'VBZ'),
#  ('identified', 'VBN'),
#  ('two', 'CD'),
#  ('places', 'NNS'),
#  ('in', 'IN'),
#  ('Whitehorse', 'NNP'),
#  ('—', 'VBP'),
#  ('a', 'DT'),
#  ('church', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('dental', 'JJ'),
#  ('clinic', 'NN'),
#  ('—', 'NN'),
#  ('where', 'WRB'),
#  ('people', 'NNS'),
#  ('may', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('exposed', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('coronavirus', 'NN'),
#  ('in', 'IN'),
#  ('recent', 'JJ'),
#  ('weeks', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('a', 'DT'),
#  ('news', 'NN'),
#  ('release', 'NN'),
#  ('Thursday', 'NNP'),
#  ('evening', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('said', 'VBD'),
#  ('anybody', 'NN'),
#  ('who', 'WP'),
#  ('went', 'VBD'),
#  ('to', 'TO'),
#  ('either', 'DT'),
#  ('place', 'NN'),
#  ('on', 'IN'),
#  ('certain', 'JJ'),
#  ('days', 'NNS'),
#  ('should', 'MD'),
#  ('monitor', 'VB'),
#  ('themselves', 'PRP'),
#  ('for', 'IN'),
#  ('symptoms', 'NNS'),
#  ('that', 'WDT'),
#  ('may', 'MD'),
#  ('indicate', 'VB'),
#  ('COVID-19', 'NNP'),
#  ('—', 'NNP'),
#  ('fever', 'NN'),
#  (',', ','),
#  ('cough', 'NN'),
#  ('or', 'CC'),
#  ('difficulty', 'NN'),
#  ('breathing', 'NN'),
#  ('—', 'NN'),
#  ('for', 'IN'),
#  ('up', 'IN'),
#  ('to', 'TO'),
#  ('14', 'CD'),
#  ('days', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('call', 'VB'),
#  ('811', 'CD'),
#  ('if', 'IN'),
#  ('those', 'DT'),
#  ('symptoms', 'NNS'),
#  ('develop', 'VBP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('possible', 'JJ'),
#  ('sources', 'NNS'),
#  ('of', 'IN'),
#  ('exposure', 'NN'),
#  ('are', 'VBP'),
#  (':', ':'),
#  ('Sunday', 'NNP'),
#  ('morning', 'NN'),
#  ('services', 'NNS'),
#  ('at', 'IN'),
#  ('Bethany', 'NNP'),
#  ('Church', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Alaska', 'NNP'),
#  ('Highway', 'NNP'),
#  (',', ','),
#  ('on', 'IN'),
#  ('March', 'NNP'),
#  ('8', 'CD'),
#  ('and', 'CC'),
#  ('March', 'NNP'),
#  ('15', 'CD'),
#  (',', ','),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('church', 'NN'),
#  ("'s", 'POS'),
#  ('``', '``'),
#  ('Kids', 'NNP'),
#  ('Zone', 'NNP'),
#  ("''", "''"),
#  ('on', 'IN'),
#  ('March', 'NNP'),
#  ('8', 'CD'),
#  ('.', '.'),
#  ('Elias', 'NNP'),
#  ('Dental', 'NNP'),
#  ('clinic', 'NN'),
#  (',', ','),
#  ('from', 'IN'),
#  ('March', 'NNP'),
#  ('9', 'CD'),
#  ('to', 'TO'),
#  ('13', 'CD'),
#  (',', ','),
#  ('or', 'CC'),
#  ('March', 'NNP'),
#  ('16', 'CD'),
#  ('.', '.'),
#  ('According', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('news', 'NN'),
#  ('release', 'NN'),
#  (',', ','),
#  ('those', 'DT'),
#  ('places', 'NNS'),
#  ('were', 'VBD'),
#  ('visited', 'VBN'),
#  ('on', 'IN'),
#  ('those', 'DT'),
#  ('dates', 'NNS'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('person', 'NN'),
#  ('or', 'CC'),
#  ('persons', 'NNS'),
#  ('who', 'WP'),
#  ('tested', 'VBD'),
#  ('positive', 'JJ'),
#  ('for', 'IN'),
#  ('COVID-19', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('also', 'RB'),
#  ('says', 'VBZ'),
#  ('that', 'IN'),
#  ('people', 'NNS'),
#  ('who', 'WP'),
#  ('attended', 'VBD'),
#  ('those', 'DT'),
#  ('places', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('identified', 'JJ'),
#  ('times', 'NNS'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('need', 'VB'),
#  ('to', 'TO'),
#  ('self-isolate', 'VB'),
#  (',', ','),
#  ('so', 'RB'),
#  ('long', 'RB'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('remain', 'VBP'),
#  ('healthy', 'JJ'),
#  ('and', 'CC'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('develop', 'VB'),
#  ('symptoms', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('risk', 'NN'),
#  ('to', 'TO'),
#  ('individuals', 'NNS'),
#  ('from', 'IN'),
#  ('both', 'DT'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('possible', 'JJ'),
#  ('exposures', 'NNS'),
#  ('is', 'VBZ'),
#  ('low', 'JJ'),
#  (',', ','),
#  ("''", "''"),
#  ('the', 'DT'),
#  ('release', 'NN'),
#  ('says', 'VBZ'),
#  ('.', '.'),
#  ('Bethany', 'NNP'),
#  ('Church', 'NNP'),
#  ('in', 'IN'),
#  ('Whitehorse', 'NNP'),
#  ('.', '.'),
#  ('According', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Yukon', 'NNP'),
#  ('government', 'NN'),
#  (',', ','),
#  ('someone', 'NN'),
#  ('who', 'WP'),
#  ('later', 'RB'),
#  ('tested', 'VBD'),
#  ('positive', 'JJ'),
#  ('for', 'IN'),
#  ('COVID-19', 'NNP'),
#  ('attended', 'VBD'),
#  ('Sunday', 'NNP'),
#  ('morning', 'NN'),
#  ('services', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('church', 'NN'),
#  ('on', 'IN'),
#  ('Mar', 'NNP'),
#  ('.', '.'),
#  ('8', 'CD'),
#  ('and', 'CC'),
#  ('15', 'CD'),
#  ('.', '.'),
#  ('(', '('),
#  ('Paul', 'NNP'),
#  ('Tukker/CBC', 'NNP'),
#  (')', ')'),
#  ('As', 'IN'),
#  ('of', 'IN'),
#  ('Wednesday', 'NNP'),
#  (',', ','),
#  ('Yukon', 'NNP'),
#  ('had', 'VBD'),
#  ('three', 'CD'),
#  ('confirmed', 'VBN'),
#  ('cases', 'NNS'),
#  ('of', 'IN'),
#  ('COVID-19', 'NNP'),
#  ('.', '.'),
#  ('Health', 'NNP'),
#  ('officials', 'NNS'),
#  ('announced', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('two', 'CD'),
#  ('cases', 'NNS'),
#  ('on', 'IN'),
#  ('Sunday', 'NNP'),
#  (',', ','),
#  ('saying', 'VBG'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('couple', 'NN'),
#  ('from', 'IN'),
#  ('Whitehorse', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('third', 'JJ'),
#  ('person', 'NN'),
#  ("'s", 'POS'),
#  ('community', 'NN'),
#  ('has', 'VBZ'),
#  ('not', 'RB'),
#  ('been', 'VBN'),
#  ('disclosed', 'VBN'),
#  ('.', '.'),
#  ('Yukon', 'CC'),
#  ('bans', 'VBZ'),
#  ('residential', 'JJ'),
#  ('evictions', 'NNS'),
#  (',', ','),
#  ('offers', 'NNS'),
#  ('paid', 'VBD'),
#  ('sick', 'JJ'),
#  ('leave', 'NN'),
#  ('during', 'IN'),
#  ('COVID-19', 'NNP'),
#  ('pandemicCOVID-19', 'JJ'),
#  ('testing', 'NN'),
#  ('centre', 'NN'),
#  ('up', 'RB'),
#  ('and', 'CC'),
#  ('running', 'VBG'),
#  ('in', 'IN'),
#  ('Whitehorse', 'NNP'),
#  ('The', 'DT'),
#  ('person', 'NN'),
#  ('or', 'CC'),
#  ('people', 'NNS'),
#  ('who', 'WP'),
#  ('attended', 'VBD'),
#  ('Bethany', 'NNP'),
#  ('Church', 'NNP'),
#  ('and', 'CC'),
#  ('Elias', 'NNP'),
#  ('Dental', 'NNP'),
#  ('are', 'VBP'),
#  ('recovering', 'VBG'),
#  ('at', 'IN'),
#  ('home', 'NN'),
#  (',', ','),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ("'s", 'POS'),
#  ('news', 'NN'),
#  ('release', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('also', 'RB'),
#  ('says', 'VBZ'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('no', 'DT'),
#  ('ongoing', 'VBG'),
#  ('risk', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('community', 'NN'),
#  ('associated', 'VBN'),
#  ('with', 'IN'),
#  ('either', 'CC'),
#  ('the', 'DT'),
#  ('church', 'NN'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('dental', 'JJ'),
#  ('clinic', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Senate', 'NNP'),
#  ('late', 'JJ'),
#  ('Wednesday', 'NNP'),
#  ('passed', 'VBD'),
#  ('an', 'DT'),
#  ('unparalleled', 'JJ'),
#  ('$', '$'),
#  ('2.2', 'CD'),
#  ('trillion', 'CD'),
#  ('US', 'NNP'),
#  ('economic', 'JJ'),
#  ('rescue', 'NN'),
#  ('package', 'NN'),
#  ('steering', 'VBG'),
#  ('aid', 'NN'),
#  ('to', 'TO'),
#  ('businesses', 'NNS'),
#  (',', ','),
#  ('workers', 'NNS'),
#  ('and', 'CC'),
#  ('health', 'NN'),
#  ('care', 'NN'),
#  ('systems', 'NNS'),
#  ('engulfed', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('coronavirus', 'NN'),
#  ('pandemic', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('unanimous', 'JJ'),
#  ('vote', 'NN'),
#  ('came', 'VBD'),
#  ('despite', 'IN'),
#  ('misgivings', 'NNS'),
#  ('on', 'IN'),
#  ('both', 'DT'),
#  ('sides', 'NNS'),
#  ('about', 'IN'),
#  ('whether', 'IN'),
#  ('it', 'PRP'),
#  ('goes', 'VBZ'),
#  ('too', 'RB'),
#  ('far', 'RB'),
#  ('or', 'CC'),
#  ('not', 'RB'),
#  ('far', 'RB'),
#  ('enough', 'RB'),
#  ('and', 'CC'),
#  ('capped', 'VBD'),
#  ('days', 'NNS'),
#  ('of', 'IN'),
#  ('difficult', 'JJ'),
#  ('negotiations', 'NNS'),
#  ('as', 'IN'),
#  ('Washington', 'NNP'),
#  ('confronted', 'VBD'),
#  ('a', 'DT'),
#  ('national', 'JJ'),
#  ('challenge', 'NN'),
#  ('unlike', 'IN'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('ever', 'RB'),
#  ('faced', 'VBN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('880-page', 'JJ'),
#  ('measure', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('economic', 'JJ'),
#  ('relief', 'NN'),
#  ('bill', 'NN'),
#  ('in', 'IN'),
#  ('U.S.', 'NNP'),
#  ('history', 'NN'),
#  ('.', '.'),
#  ('Republican', 'JJ'),
#  ('Senate', 'NNP'),
#  ('Majority', 'NNP'),
#  ('Leader', 'NNP'),
#  ('Mitch', 'NNP'),
#  ('McConnell', 'NNP'),
#  ('appeared', 'VBD'),
#  ('sombre', 'NN'),
#  ('and', 'CC'),
#  ('exhausted', 'VBD'),
#  ('as', 'IN'),
#  ('he', 'PRP'),
#  ('announced', 'VBD'),
#  ('the', 'DT'),
#  ('vote', 'NN'),
#  ('—', 'NN'),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('released', 'VBD'),
#  ('senators', 'NNS'),
#  ('from', 'IN'),
#  ('Washington', 'NNP'),
#  ('until', 'IN'),
#  ('April', 'NNP'),
#  ('20', 'CD'),
#  (',', ','),
#  ('though', 'IN'),
#  ('he', 'PRP'),
#  ('promised', 'VBD'),
#  ('to', 'TO'),
#  ('recall', 'VB'),
#  ('them', 'PRP'),
#  ('if', 'IN'),
#  ('needed', 'VBN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('legislation', 'NN'),
#  ('now', 'RB'),
#  ('before', 'IN'),
#  ('us', 'PRP'),
#  ('now', 'RB'),
#  ('is', 'VBZ'),
#  ('historic', 'JJ'),
#  ('because', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('meant', 'VBN'),
#  ('to', 'TO'),
#  ('match', 'VB'),
#  ('a', 'DT'),
#  ('historic', 'JJ'),
#  ('crisis', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Democratic', 'JJ'),
#  ('Senate', 'NNP'),
#  ('Minority', 'NNP'),
#  ('Leader', 'NNP'),
#  ('Chuck', 'NNP'),
#  ('Schumer', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Our', 'PRP$'),
#  ('health', 'NN'),
#  ('care', 'NN'),
#  ('system', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('prepared', 'JJ'),
#  ('to', 'TO'),
#  ('care', 'VB'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('sick', 'NN'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('workers', 'NNS'),
#  ('are', 'VBP'),
#  ('without', 'IN'),
#  ('work', 'NN'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('businesses', 'NNS'),
#  ('can', 'MD'),
#  ('not', 'RB'),
#  ('do', 'VB'),
#  ('business', 'NN'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('factories', 'NNS'),
#  ('lie', 'VBP'),
#  ('idle', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('gears', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('American', 'JJ'),
#  ('economy', 'NN'),
#  ('have', 'VBP'),
#  ('ground', 'VBN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('halt', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('WATCH', 'NNP'),
#  ('|', 'NNP'),
#  ('U.S.', 'NNP'),
#  ('closer', 'NN'),
#  ('to', 'TO'),
#  ('passing', 'VBG'),
#  ('aid', 'JJ'),
#  ('package', 'NN'),
#  ('as', 'IN'),
#  ('Louisiana', 'NNP'),
#  ('becomes', 'VBZ'),
#  ('potential', 'JJ'),
#  ('hotspot', 'NN'),
#  (':', ':'),
#  ('American', 'JJ'),
#  ('lawmakers', 'NNS'),
#  ('are', 'VBP'),
#  ('confident', 'JJ'),
#  ('an', 'DT'),
#  ('aid', 'NN'),
#  ('package', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('approved', 'VBN'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('as', 'IN'),
#  ...]

# %% [markdown]
# ## Named Entity Recognition
# Sentences in different languagues follow some kind of a structure (or grammar), where each part of a speech has its  position in the sentence. Also, sentences contain something called sentence elements. For example, those are subject, verb or object and more. From that we can determine what is a sentence about. **Named entity** is a subject or an object, that can be denoted with a proper name. The marking process finds patterns in the sentence. Technically, the sentences is a tree-like structure and the marking process finds subtrees that follows the chosen pattern.
#
#
# **The following text is only about differences in Czech an English, nothing important for this task. I was just thinking how the marking of sentence elements differs from English to Czech.**
#
# English has a very strict sentence structure in comparison to Czech language. Thus, RegEx expressions for marking sentence elements in Czech language would be more of a challenge, because position of words in Czech sentence can be at different positions and still have the same meaning.
#
# Howerever, the position of the word is sometimes crutial for the meaning of the sentence. Also, sentence elements are not ambiguous and object could be easily mistaken for the subject, for example. From that, it is really quite challenging to understand Czech language, even for natives.
#
# For example:
#
# **"Manželství vám zachrání kampaň."**<br>
# Can be translated into English as:<br>
# **"A marriage will be saved by a campaign."**<br>
# or:<br>
# **"A marriage will save by a campaign."**<br>
# Both sentences has totally different meaning in English, but in Czech we do not know, until we get it from context.

# %%
ne_chunked = nltk.ne_chunk(tagged, binary=True)
name_entities_orig = extract_entities(ne_chunked)
name_entities_orig
# Out:
# {'Canadian': 'NE',
#  'India': 'NE',
#  'China': 'NE',
#  'Canadian Pharmacists Association': 'NE',
#  'Mina Tadrous': 'NE',
#  'Toronto': 'NE',
#  'U.S.': 'NE',
#  'Tadrous': 'NE',
#  'Canada': 'NE',
#  'Queen': 'NE',
#  'Kingston': 'NE',
#  'North America': 'NE',
#  'Kas': 'NE',
#  'Duffin': 'NE',
#  'refillsNew Brunswick': 'NE',
#  'Europe': 'NE',
#  'Yukon': 'NE',
#  'Whitehorse': 'NE',
#  'Bethany Church': 'NE',
#  'Alaska Highway': 'NE',
#  'Elias Dental': 'NE',
#  'Paul': 'NE',
#  'Senate': 'NE',
#  'Washington': 'NE',
#  'Republican': 'NE',
#  'Senate Majority Leader Mitch': 'NE',
#  'McConnell': 'NE',
#  'Democratic': 'NE',
#  'Senate Minority Leader Chuck Schumer': 'NE',
#  'American': 'NE',
#  'WATCH': 'NE',
#  'Louisiana': 'NE',
#  'Treasury': 'NE',
#  'Steven Mnuchin': 'NE',
#  'Donald Trump': 'NE',
#  'New York': 'NE',
#  'New York Gov': 'NE',
#  'Andrew Cuomo': 'NE',
#  'Washington Democrats': 'NE',
#  'Congress': 'NE',
#  'Democratic House': 'NE',
#  'House': 'NE',
#  'House Democratic': 'NE',
#  'Trump': 'NE',
#  'Capitol Hill': 'NE',
#  'Tom': 'NE',
#  'Democrats': 'NE',
#  'Social': 'NE',
#  'Manitoba': 'NE',
#  'University': 'NE',
#  'Minnesota': 'NE',
#  'Alberta': 'NE',
#  'McGill University Health Centre': 'NE',
#  'Zarychanski': 'NE',
#  'Mount Sinai': 'NE',
#  'COVID19': 'NE',
#  'IcahnMountSinai': 'NE',
#  'Montreal Heart': 'NE',
#  'Mediterranean': 'NE',
#  'Montreal Heart Institute': 'NE',
#  'CBC Montreal': 'NE',
#  'Military Medical Sciences': 'NE',
#  'Kaiser Permanente Washington Research Institute': 'NE',
#  'Seattle': 'NE',
#  'Quarantine Act': 'NE',
#  'Winnipeg': 'NE',
#  'Assiniboine Park': 'NE',
#  'Trevor': 'NE',
#  'Trudeau': 'NE',
#  'Justin Trudeau': 'NE',
#  'Ontario': 'NE',
#  'Doug Ford': 'NE',
#  'Jason Kenney': 'NE',
#  'Ottawa': 'NE',
#  'Chrystia Freeland': 'NE',
#  'White House': 'NE',
#  'CBC News': 'NE',
#  'Guojian Huang': 'NE',
#  'Chinese': 'NE',
#  'SARS': 'NE',
#  'ANALYSIS Chris Hadfield': 'NE',
#  'Astronaut Chris Hadfield': 'NE',
#  'International Space Station': 'NE',
#  'Hadfield': 'NE',
#  'CBC': 'NE',
#  'SCIENCE': 'NE',
#  'Public Health Agency': 'NE',
#  'U.S. Centers': 'NE',
#  'Disease Control': 'NE',
#  'FINALLY': 'NE',
#  'Gareth': 'NE',
#  'Major League Baseball': 'NE',
#  'Coronavirus Brief': 'NE',
#  'Kanopy': 'NE',
#  'National Film Board': 'NE',
#  'Indigenous': 'NE',
#  'MLB': 'NE',
#  'Click': 'NE',
#  'CBC News Network': 'NE',
#  'Kerry Bowman': 'NE',
#  'Dalla Lana School': 'NE',
#  'Public Health': 'NE',
#  'Wuhan': 'NE',
#  'Bowman': 'NE',
#  'Severe Acute Respiratory Syndrome': 'NE',
#  'Ebola': 'NE',
#  'Middle East Respiratory Syndrome': 'NE',
#  'MERS': 'NE',
#  'China Bowman': 'NE',
#  'Asia': 'NE',
#  'Far East': 'NE',
#  'Vietnam': 'NE',
#  'Southeast Asia': 'NE',
#  'Indonesia': 'NE',
#  'Liuan': 'NE',
#  'Asian': 'NE',
#  'Jason Stull': 'NE',
#  'Prince Edward Island': 'NE',
#  'Atlantic Veterinary College': 'NE',
#  'Stull': 'NE',
#  'EcoHealth Alliance': 'NE',
#  'William Karesh': 'NE',
#  'Karesh': 'NE',
#  'Quebec': 'NE',
#  'Brockville': 'NE',
#  'Memorial Centre': 'NE',
#  'NCC': 'NE',
#  'Greenbelt': 'NE',
#  'Ottawa Hospital': 'NE',
#  'Montfort': 'NE',
#  'Queensway Carleton': 'NE',
#  'LISTEN': 'NE',
#  'Ottawa Public Health': 'NE',
#  'Vera Etches': 'NE',
#  'Eastern Ontario': 'NE',
#  'Champlain Bridge': 'NE',
#  'Gatineau': 'NE',
#  'Francis': 'NE',
#  'Ontario Provincial': 'NE',
#  'Park': 'NE',
#  'Local Daily': 'NE',
#  'Adrian Harewood': 'NE',
#  'Omar': 'NE',
#  'Ottawa Ontario': 'NE',
#  'Health': 'NE',
#  'Brewer Arena': 'NE',
#  'Bronson Avenue': 'NE',
#  'Carleton University': 'NE',
#  'Ottawa Inner City Health': 'NE',
#  'Ont': 'NE',
#  'Kingston Memorial Centre': 'NE',
#  'Telehealth': 'NE',
#  'Belleville': 'NE',
#  'Leeds': 'NE',
#  'Grenville': 'NE',
#  'Lanark': 'NE',
#  'Brockville Memorial Centre': 'NE',
#  'Hawkesbury': 'NE',
#  'Viera Zmiyiwsky': 'NE',
#  'Renfrew County': 'NE',
#  'Outaouais': 'NE',
#  'Mohawk': 'NE',
#  'Akwesasne': 'NE',
#  'Mohawks': 'NE',
#  'Quinte': 'NE',
#  'MBQ': 'NE',
#  'Algonquin': 'NE',
#  'Kitigan Zibi': 'NE',
#  'Pikwakanagan': 'NE',
#  'Ontario Ministry': 'NE',
#  'Centre': 'NE',
#  'French': 'NE',
#  'Wayne': 'NE',
#  'Oakland': 'NE',
#  'Macomb': 'NE',
#  'Upper Peninsula': 'NE',
#  'Beaumont Health': 'NE',
#  'Henry Ford Health System': 'NE',
#  'Michigan': 'NE',
#  'Grand Rapids': 'NE',
#  'CBC News Windsor': 'NE',
#  'Italy': 'NE',
#  'Johns Hopkins University': 'NE',
#  'New Orleans': 'NE',
#  'CDC': 'NE',
#  'EPA': 'NE',
#  'U.S. House': 'NE',
#  'Dow Jones': 'NE',
#  'Dow': 'NE',
#  'United States': 'NE',
#  'Cuomo': 'NE',
#  'Elmhurst Hospital Center': 'NE',
#  'New York City': 'NE',
#  'John': 'NE',
#  'Navarro': 'NE',
#  'Detroit': 'NE',
#  'Chicago': 'NE',
#  'California': 'NE',
#  'LATESTCoronavirus': 'NE',
#  'National Institute': 'NE',
#  'Allergy': 'NE',
#  'Infectious Diseases': 'NE',
#  'Fauci': 'NE',
#  'WNYC': 'NE',
#  'New Jersey Gov': 'NE',
#  'Phil Murphy': 'NE',
#  'Georgia': 'NE',
#  'Albany': 'NE',
#  'Bourbon Street': 'NE',
#  'Jonathan': 'NE',
#  'Scott Steiner': 'NE',
#  'CEO': 'NE',
#  'Phoebe Putney Memorial Hospital': 'NE',
#  'Phoebe Putney': 'NE',
#  'Dougherty County': 'NE',
#  'Warner Thomas': 'NE',
#  'Ochsner Medical Center': 'NE',
#  'Thomas': 'NE',
#  'Hospitals': 'NE',
#  'Pelosi': 'NE',
#  'Powell': 'NE',
#  'Easter': 'NE',
#  'NBC': 'NE',
#  'Danni Askini': 'NE',
#  'Mark Esper': 'NE',
#  'Esper': 'NE',
#  'Reuters': 'NE',
#  'Cavendish Mall': 'NE',
#  'Francine Dupuis': 'NE',
#  'CIUSSS Central': 'NE',
#  'Dupuis': 'NE',
#  'Montreal': 'NE',
#  'Senior': 'NE',
#  'CIUSSS': 'NE',
#  'Hospital': 'NE',
#  'ICU': 'NE',
#  'Hong Kong': 'NE',
#  'European': 'NE',
#  'Regina': 'NE',
#  'Saskatchewan': 'NE',
#  'Rally': 'NE',
#  'Saskatchewan Health Authority': 'NE',
#  'Lakeland Tree Dodgers Snowmobile Club': 'NE',
#  'Lakeland': 'NE',
#  'Prince Albert': 'NE',
#  'Lakeland Snowmobile Club Wilderness Rally Supper': 'NE',
#  'Christopher Lake': 'NE',
#  'Photos': 'NE',
#  'Lakeland Tree Dodgers Snowmobile': 'NE',
#  'Facebook': 'NE',
#  'Albert Communicable Disease Team': 'NE',
#  'Sask': 'NE',
#  'Pacific Dental Conference': 'NE',
#  'Vancouver Convention Centre': 'NE',
#  'Saskatoon': 'NE',
#  'Edmonton': 'NE',
#  'Vancouver': 'NE',
#  'Shahab': 'NE',
#  'Ministry': 'NE',
#  'Justice': 'NE',
#  'Don Morgan': 'NE',
#  'Morgan': 'NE',
#  'CANADIAN': 'NE',
#  'Cuban': 'NE',
#  'First Nations': 'NE',
#  'Southern Chiefs Organization Grand': 'NE',
#  'Daniels': 'NE',
#  'Cuban Health Care Brigades': 'NE',
#  'Anishnaabe': 'NE',
#  'Dakota': 'NE',
#  'Southern Chiefs': 'NE',
#  'Indigenous Services Canada': 'NE',
#  'ISC': 'NE',
#  'Cuba': 'NE',
#  'Caribbean': 'NE',
#  'Havana': 'NE',
#  'Michelle Dubois': 'NE',
#  'Venezuela': 'NE',
#  'Nicaragua': 'NE',
#  'Jamaica': 'NE',
#  'Suriname': 'NE',
#  'Grenada': 'NE',
#  'David': 'NE',
#  'LeDoux': 'NE',
#  'David LeDoux': 'NE',
#  'Gambler First Nation': 'NE'}

# %% [markdown]
# ### Custom NER
#
# We can define the followed pattern by a regular expression. Each part of speech has its code. For example, NN is a noun, singular or mass, NNS is its plural form, VB is a verb in base form and so on. The full list is described in this link: https://cs.nyu.edu/grishman/jet/guide/PennPOS.html
#
# I have tried different regular expressions and I stood with the one below. Just from the observation I decided that it was the most precise one.
#
# My regular expression is:<br>
# &lt;DT&gt;? - Optional determined<br>
# &lt;JJ&gt;* - optional multiple adjective<br>
# &lt;NNP|NNOS&gt;* - proper noun in singular, mass or plural form
#
# In other words the named entity is a structure of a proper noun introduced or not introduced by a determined. It can have zero to unlimited number of adjectives.
#
# The regular expression would differ for a specific use case. For example, the restrictions would have been more strict if false positives could do much more damage than true negatives.

# %%
grammar = "NE: {<DT>?<JJ>*<NNP|NNPS>}"
cp = nltk.RegexpParser(grammar)
custom_ne_chunked = cp.parse(tagged)
name_entities_custom = extract_entities(custom_ne_chunked)
name_entities_custom
# Out:
# {'India': 'NE',
#  'China': 'NE',
#  'COVID-19': 'NE',
#  'Provincial': 'NE',
#  'the Canadian': 'NE',
#  'Pharmacists': 'NE',
#  'Association': 'NE',
#  'Mina': 'NE',
#  'Tadrous': 'NE',
#  'Toronto': 'NE',
#  'worried Canadians': 'NE',
#  'the U.S.': 'NE',
#  'Canada': 'NE',
#  'Ongoing': 'NE',
#  'Dr.': 'NE',
#  'Jacalyn': 'NE',
#  'Duffin': 'NE',
#  'Queen': 'NE',
#  'University': 'NE',
#  'Kingston': 'NE',
#  'Ont.': 'NE',
#  'North': 'NE',
#  'America': 'NE',
#  'Kas': 'NE',
#  'Roussy/CBC': 'NE',
#  'Brunswick': 'NE',
#  'outbreak India': 'NE',
#  'Europe': 'NE',
#  'Whitehorse': 'NE',
#  'Thursday': 'NE',
#  '—': 'NE',
#  'Sunday': 'NE',
#  'Bethany': 'NE',
#  'Church': 'NE',
#  'the Alaska': 'NE',
#  'Highway': 'NE',
#  'March': 'NE',
#  'Kids': 'NE',
#  'Zone': 'NE',
#  'Elias': 'NE',
#  'Dental': 'NE',
#  'the Yukon': 'NE',
#  'Mar': 'NE',
#  'Paul': 'NE',
#  'Tukker/CBC': 'NE',
#  'Wednesday': 'NE',
#  'Yukon': 'NE',
#  'Health': 'NE',
#  'The Senate': 'NE',
#  'late Wednesday': 'NE',
#  'US': 'NE',
#  'Washington': 'NE',
#  'U.S.': 'NE',
#  'Republican Senate': 'NE',
#  'Majority': 'NE',
#  'Leader': 'NE',
#  'Mitch': 'NE',
#  'McConnell': 'NE',
#  'April': 'NE',
#  'Democratic Senate': 'NE',
#  'Minority': 'NE',
#  'Chuck': 'NE',
#  'Schumer': 'NE',
#  'WATCH': 'NE',
#  '|': 'NE',
#  'Louisiana': 'NE',
#  'Treasury': 'NE',
#  'Secretary': 'NE',
#  'Steven': 'NE',
#  'Mnuchin': 'NE',
#  'Hopefully': 'NE',
#  'Insistently': 'NE',
#  'President': 'NE',
#  'Donald': 'NE',
#  'Trump': 'NE',
#  'Coronavirus': 'NE',
#  'New': 'NE',
#  'York': 'NE',
#  'the Senate': 'NE',
#  'conservative Republican': 'NE',
#  'Gov': 'NE',
#  'Andrew': 'NE',
#  'Cuomo': 'NE',
#  'a prominent Democrat': 'NE',
#  'Rep.': 'NE',
#  'Alexandria': 'NE',
#  'Ocasio-Cortez': 'NE',
#  'top Washington': 'NE',
#  'Democrats': 'NE',
#  'Congress': 'NE',
#  'Democratic House': 'NE',
#  'Speaker': 'NE',
#  'Nancy': 'NE',
#  'Pelosi': 'NE',
#  'Senate': 'NE',
#  'the Democratic-controlled': 'NE',
#  'House': 'NE',
#  'Friday': 'NE',
#  'Americans': 'NE',
#  'Six': 'NE',
#  'Capitol': 'NE',
#  'Police': 'NE',
#  'Hill': 'NE',
#  'Tom': 'NE',
#  'Brenner/Reuters': 'NE',
#  'the Federal': 'NE',
#  'Emergency': 'NE',
#  'Management': 'NE',
#  'Agency': 'NE',
#  'Uber': 'NE',
#  'Republicans': 'NE',
#  'Social': 'NE',
#  'Security': 'NE',
#  'Old': 'NE',
#  'Manitoba': 'NE',
#  'the University': 'NE',
#  'Minnesota': 'NE',
#  'Alberta': 'NE',
#  'McGill': 'NE',
#  'Centre': 'NE',
#  'Ryan': 'NE',
#  'Zarychanski': 'NE',
#  'Mount': 'NE',
#  'Sinai': 'NE',
#  '@': 'NE',
#  'MountSinaiNYC': 'NE',
#  '<': 'NE',
#  '/a': 'NE',
#  '>': 'NE',
#  'COVID19': 'NE',
#  '//t.co/bpSB2HuSqR <': 'NE',
#  '< /a': 'NE',
#  'IcahnMountSinai': 'NE',
#  'the Montreal': 'NE',
#  'Heart': 'NE',
#  'Institute': 'NE',
#  'Behçet': 'NE',
#  'familial Mediterranean': 'NE',
#  'Montreal': 'NE',
#  'Jean-Claude': 'NE',
#  'Tardif': 'NE',
#  'CBC': 'NE',
#  'Daybreak': 'NE',
#  'potential COVID-19': 'NE',
#  'a Saskatoon': 'NE',
#  'Academy': 'NE',
#  'Military': 'NE',
#  'Medical': 'NE',
#  'Sciences': 'NE',
#  'the Kaiser': 'NE',
#  'Permanente': 'NE',
#  'Research': 'NE',
#  'Seattle': 'NE',
#  'a potential COVID-19': 'NE',
#  'Trudeau': 'NE',
#  'Quarantine': 'NE',
#  'Act': 'NE',
#  'Winnipeg': 'NE',
#  'Assiniboine': 'NE',
#  'Park': 'NE',
#  'Trevor': 'NE',
#  'Brine/CBC': 'NE',
#  'the Quarantine': 'NE',
#  'all Canadians': 'NE',
#  'Prime': 'NE',
#  'Minister': 'NE',
#  'Justin': 'NE',
#  'Ontario': 'NE',
#  'Doug': 'NE',
#  'Ford': 'NE',
#  'Jason': 'NE',
#  'Kenney': 'NE',
#  'Ottawa': 'NE',
#  'Read': 'NE',
#  'Deputy': 'NE',
#  'Chrystia': 'NE',
#  'Freeland': 'NE',
#  'White': 'NE',
#  'News': 'NE',
#  'the White': 'NE',
#  'a Winnipeg': 'NE',
#  'Guojian': 'NE',
#  'Huang': 'NE',
#  'a Health': 'NE',
#  'A Toronto': 'NE',
#  'the SARS': 'NE',
#  'Peter': 'NE',
#  'Lin': 'NE',
#  'ANALYSIS': 'NE',
#  'Chris': 'NE',
#  'Hadfield': 'NE',
#  'Astronaut': 'NE',
#  'the International': 'NE',
#  'Space': 'NE',
#  'Station': 'NE',
#  'Heather': 'NE',
#  'Hiscox': 'NE',
#  'Anything': 'NE',
#  'THE SCIENCE': 'NE',
#  'The Public': 'NE',
#  'Centers': 'NE',
#  'Disease': 'NE',
#  'Control': 'NE',
#  'Prevention': 'NE',
#  'World': 'NE',
#  'Organization': 'NE',
#  'Rama': 'NE',
#  'Nair': 'NE',
#  'FINALLY': 'NE',
#  'Gareth': 'NE',
#  'Copley/Getty': 'NE',
#  'Images': 'NE',
#  'Opening': 'NE',
#  'Day': 'NE',
#  'the Major': 'NE',
#  'League': 'NE',
#  'Baseball': 'NE',
#  'a certain Coronavirus': 'NE',
#  'Brief': 'NE',
#  'Kanopy': 'NE',
#  'The National': 'NE',
#  'Film': 'NE',
#  'Board': 'NE',
#  'Indigenous': 'NE',
#  'MLB': 'NE',
#  '//www.cbc.ca/news/entertainment/free-family-streaming-covid-19-stay-at-home-1.5509556 Send': 'NE',
#  'local CBC': 'NE',
#  'Click': 'NE',
#  'Network': 'NE',
#  'Kerry': 'NE',
#  'Bowman': 'NE',
#  'Dalla': 'NE',
#  'Lana': 'NE',
#  'School': 'NE',
#  'Public': 'NE',
#  'Wuhan': 'NE',
#  'Spillover': 'NE',
#  'Severe': 'NE',
#  'Acute': 'NE',
#  'Respiratory': 'NE',
#  'Syndrome': 'NE',
#  'SARS': 'NE',
#  'primatologist Jane': 'NE',
#  'Goodall': 'NE',
#  'The Ebola': 'NE',
#  'central Africa': 'NE',
#  'Middle': 'NE',
#  'East': 'NE',
#  'MERS': 'NE',
#  'Asia': 'NE',
#  'the Far': 'NE',
#  'Vietnam': 'NE',
#  'Southeast': 'NE',
#  'Indonesia': 'NE',
#  'Civet': 'NE',
#  'Liuan': 'NE',
#  'Photos/Getty': 'NE',
#  'February': 'NE',
#  'Stull': 'NE',
#  'Prince': 'NE',
#  'Edward': 'NE',
#  'Island': 'NE',
#  'Atlantic': 'NE',
#  'Veterinary': 'NE',
#  'College': 'NE',
#  'the EcoHealth': 'NE',
#  'Alliance': 'NE',
#  'a New': 'NE',
#  'William': 'NE',
#  'Karesh': 'NE',
#  'How': 'NE',
#  'Focus': 'NE',
#  'God': 'NE',
#  'western Quebec': 'NE',
#  'Brockville': 'NE',
#  'the Memorial': 'NE',
#  'NCC': 'NE',
#  'Greenbelt': 'NE',
#  'The Ottawa': 'NE',
#  'Hospital': 'NE',
#  'The Montfort': 'NE',
#  'Queensway': 'NE',
#  'Carleton': 'NE',
#  'LISTEN': 'NE',
#  'Critical': 'NE',
#  'Willmore': 'NE',
#  'the Ottawa': 'NE',
#  'Vera': 'NE',
#  'Etches': 'NE',
#  '’': 'NE',
#  'Eastern': 'NE',
#  'Quebec': 'NE',
#  'The Champlain': 'NE',
#  'Bridge': 'NE',
#  'Gatineau': 'NE',
#  'Francis': 'NE',
#  'Ferland/CBC': 'NE',
#  'Sports': 'NE',
#  'May': 'NE',
#  'Local Daily': 'NE',
#  'Lucy': 'NE',
#  'Oldenbarneveld': 'NE',
#  'Adrian': 'NE',
#  'Harewood': 'NE',
#  'Omar': 'NE',
#  'Dabaghi-Pacheco': 'NE',
#  'the COVID-19': 'NE',
#  'Service': 'NE',
#  'Ministry': 'NE',
#  'coronavirus Ottawa': 'NE',
#  'Doctors': 'NE',
#  'Symptoms': 'NE',
#  'Canadians': 'NE',
#  'the pandemic How': 'NE',
#  'Anyone': 'NE',
#  'the Brewer': 'NE',
#  'Arena': 'NE',
#  'Brewer': 'NE',
#  'Way': 'NE',
#  'Bronson': 'NE',
#  'Avenue': 'NE',
#  'Wendy': 'NE',
#  'Muckle': 'NE',
#  'Inner': 'NE',
#  'City': 'NE',
#  'Outaouais': 'NE',
#  'Ont': 'NE',
#  'the Kingston': 'NE',
#  'Memorial': 'NE',
#  'St': 'NE',
#  'Telehealth': 'NE',
#  'the Belleville': 'NE',
#  'Leeds': 'NE',
#  'Grenville': 'NE',
#  'Lanark': 'NE',
#  'the Brockville': 'NE',
#  'Magedoma': 'NE',
#  'Blvd': 'NE',
#  'Hawkesbury': 'NE',
#  'Laurier': 'NE',
#  'St.': 'NE',
#  'Monday': 'NE',
#  'Viera': 'NE',
#  'Zmiyiwsky': 'NE',
#  'Renfrew': 'NE',
#  'County': 'NE',
#  'Telehealth\u200b\u200b\u200b': 'NE',
#  'the Outaouais': 'NE',
#  'First Nations': 'NE',
#  'The Mohawk': 'NE',
#  'Akwesasne': 'NE',
#  'Mohawks': 'NE',
#  'the Bay': 'NE',
#  'Quinte': 'NE',
#  'MBQ': 'NE',
#  'The Algonquin': 'NE',
#  'Kitigan': 'NE',
#  'Zibi': 'NE',
#  'Pikwakanagan': 'NE',
#  'Saturday': 'NE',
#  'local eastern Ontario': 'NE',
#  'the Ontario': 'NE',
#  'the Public': 'NE',
#  'the Centre': 'NE',
#  'French': 'NE',
#  'Michigan': 'NE',
#  'Wayne': 'NE',
#  'Oakland': 'NE',
#  'Macomb': 'NE',
#  'the Upper': 'NE',
#  'Peninsula': 'NE',
#  'Beaumont': 'NE',
#  'Henry': 'NE',
#  'System': 'NE',
#  'southeastern Michigan': 'NE',
#  'Altus': 'NE',
#  'Grand': 'NE',
#  'Rapids': 'NE',
#  'Windsor': 'NE',
#  'governorFront-line ER': 'NE',
#  'COVID-19PhotosWindsor': 'NE',
#  'Islamic': 'NE',
#  'both Italy': 'NE',
#  'Johns': 'NE',
#  'Hopkins': 'NE',
#  'Orleans': 'NE',
#  'The U.S.': 'NE',
#  'CDC': 'NE',
#  'Tuesday': 'NE',
#  'ET': 'NE',
#  'the Trump': 'NE',
#  'an Environmental Protection': 'NE',
#  'AnalysisPoliticians': 'NE',
#  'Don': 'NE',
#  'PittisNo': 'NE',
#  'the EPA': 'NE',
#  'Representatives': 'NE',
#  'Wall': 'NE',
#  'Street': 'NE',
#  'The S': 'NE',
#  'P': 'NE',
#  'the Dow': 'NE',
#  'Jones': 'NE',
#  'the United': 'NE',
#  'States': 'NE',
#  'Elmhurst': 'NE',
#  'Center': 'NE',
#  'John': 'NE',
#  'Minchillo/The': 'NE',
#  'Associated': 'NE',
#  'Press': 'NE',
#  'Navarro': 'NE',
#  'Detroit': 'NE',
#  'Chicago': 'NE',
#  'California': 'NE',
#  'Anthony': 'NE',
#  'Fauci': 'NE',
#  'National': 'NE',
#  'Allergy': 'NE',
#  'Infectious': 'NE',
#  'Diseases': 'NE',
#  'June': 'NE',
#  'WNYC': 'NE',
#  'Jersey': 'NE',
#  'Phil': 'NE',
#  'Murphy': 'NE',
#  'Rural Georgia': 'NE',
#  'Albany': 'NE',
#  'Ga': 'NE',
#  'Georgia': 'NE',
#  'Bourbon': 'NE',
#  'Jonathan': 'NE',
#  'Bachman/Reuters': 'NE',
#  'Scott': 'NE',
#  'Steiner': 'NE',
#  'CEO': 'NE',
#  'Phoebe': 'NE',
#  'Putney': 'NE',
#  'Dougherty': 'NE',
#  'metro Atlanta': 'NE',
#  'Warner': 'NE',
#  'Thomas': 'NE',
#  'Ochsner': 'NE',
#  'Fed': 'NE',
#  'Hospitals': 'NE',
#  'Federal': 'NE',
#  'Reserve': 'NE',
#  'Chair': 'NE',
#  'Jerome': 'NE',
#  'Powell': 'NE',
#  'Easter': 'NE',
#  'NBC': 'NE',
#  'Today': 'NE',
#  'Show': 'NE',
#  'Danni': 'NE',
#  'Askini': 'NE',
#  'confirmed U.S.': 'NE',
#  'Defence': 'NE',
#  'Mark': 'NE',
#  'Esper': 'NE',
#  'Officials': 'NE',
#  'Reuters': 'NE',
#  'The Jewish General': 'NE',
#  'minor COVID-19': 'NE',
#  'the Cavendish': 'NE',
#  'Mall': 'NE',
#  'Côte': 'NE',
#  'Saint-Luc': 'NE',
#  'Francine': 'NE',
#  'Dupuis': 'NE',
#  'the associate CEO': 'NE',
#  'the CIUSSS': 'NE',
#  'Central': 'NE',
#  'West.West-Central Montreal': 'NE',
#  'Senior administrator Francine': 'NE',
#  'the Jewish General': 'NE',
#  'CIUSSS': 'NE',
#  'West-Central': 'NE',
#  'the main COVID-19': 'NE',
#  'ICU': 'NE',
#  'slow Recovery': 'NE',
#  '[': 'NE',
#  'the Hong': 'NE',
#  'Kong': 'NE',
#  'Three': 'NE',
#  'Saskatchewan': 'NE',
#  'Premier': 'NE',
#  'Moe': 'NE',
#  'a Saskatchewan': 'NE',
#  'appointment-only COVID-19': 'NE',
#  'Regina': 'NE',
#  'Rally': 'NE',
#  'positive A': 'NE',
#  'the Saskatchewan': 'NE',
#  'Authority': 'NE',
#  'the Lakeland': 'NE',
#  'Tree': 'NE',
#  'Dodgers': 'NE',
#  'Snowmobile': 'NE',
#  'Club': 'NE',
#  'Albert': 'NE',
#  'Facebook': 'NE',
#  'Wilderness': 'NE',
#  'Supper': 'NE',
#  'Christopher': 'NE',
#  'Lake': 'NE',
#  'Photos': 'NE',
#  'Lakeland': 'NE',
#  'Club/Facebook': 'NE',
#  'Just': 'NE',
#  'a March': 'NE',
#  'the Facebook': 'NE',
#  'Practice': 'NE',
#  'This Facebook': 'NE',
#  'the Prince': 'NE',
#  'Communicable': 'NE',
#  'Team': 'NE',
#  '306-765-6504': 'NE',
#  'Khami': 'NE',
#  'Chokani': 'NE',
#  'the March': 'NE',
#  'Saqib': 'NE',
#  'Shahab': 'NE',
#  'effective March': 'NE',
#  'the World': 'NE',
#  'Sask': 'NE',
#  'the Pacific': 'NE',
#  'Conference': 'NE',
#  'the Vancouver': 'NE',
#  'Convention': 'NE',
#  'Saskatoon': 'NE',
#  'an Edmonton': 'NE',
#  'Vancouver': 'NE',
#  'western Canada': 'NE',
#  'COVID-19-like': 'NE',
#  'transparency Police': 'NE',
#  'The Ministry': 'NE',
#  'Justice': 'NE',
#  'Morgan': 'NE',
#  'THE CANADIAN': 'NE',
#  'PRESS': 'NE',
#  'So': 'NE',
#  'Canadian Press': 'NE',
#  'A': 'NE',
#  'Cuban': 'NE',
#  'First': 'NE',
#  'Nations': 'NE',
#  'Southern': 'NE',
#  'Chiefs': 'NE',
#  'Chief': 'NE',
#  'Jerry': 'NE',
#  'Daniels': 'NE',
#  'Care': 'NE',
#  'Brigades': 'NE',
#  'Anishnaabe': 'NE',
#  'Dakota': 'NE',
#  'Southern Chiefs': 'NE',
#  'Gary': 'NE',
#  'Solilak/CBC': 'NE',
#  'Services': 'NE',
#  'ISC': 'NE',
#  'Cuba': 'NE',
#  'the Caribbean': 'NE',
#  'potential Indigenous': 'NE',
#  'Havana': 'NE',
#  'Michelle': 'NE',
#  'Dubois': 'NE',
#  'senior Cuban': 'NE',
#  'the Assembly': 'NE',
#  'December': 'NE',
#  'the Manitoba': 'NE',
#  'The Prime': 'NE',
#  'Office': 'NE',
#  'pandemic Cuban': 'NE',
#  'Italy': 'NE',
#  'Venezuela': 'NE',
#  'Nicaragua': 'NE',
#  'Jamaica': 'NE',
#  'Suriname': 'NE',
#  'Grenada': 'NE',
#  'Nation': 'NE',
#  'David': 'NE',
#  'LeDoux': 'NE',
#  'Gambler': 'NE',
#  'the Cuban': 'NE',
#  'the Canada': 'NE',
#  'The Cuban': 'NE'}

# %% [markdown]
# # Entity Classification
# Each entity is classified from the first sentence of its page on Wikipedia. I defined another Regular Expression that finds noun phrase in this very first sentence.
#
# I looked up for the proper regular expression of the noun phrase on the Internet, but I found many examples. Because of that, I decided that the regular expression for the noun phrase also differs for different purposes or use cases. I created my own, that returns optional nubmer of determiners, optional number of adjectives (now even with superlative and comparative adjectives) and at least one noun to unlimited number of nouns.
#
# The number of classified entities is limited to 20 for each list of named entities.

# %%
def extract_noun_phrase(ne_chunked):
    for entity in ne_chunked:
        if isinstance(entity, nltk.tree.Tree):
            text = " ".join([word for word, tag in entity.leaves()])
            return text
        else:
            continue
    return "Thing"
    
import wikipedia

# %%
count = 0;
limit = 20;

for name in name_entities_orig:
    try:
        page = wikipedia.page(name)
        sentence = nltk.sent_tokenize(page.summary)[0] 
        grammar = "NP: <VB.?>{<DT>*<JJ.*>*<NN.*>+}"
        cp = nltk.RegexpParser(grammar)
        tokens = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(tokens)
        custom_ne_chunked = cp.parse(tagged)
        print(name + " ==> "+ extract_noun_phrase(custom_ne_chunked))
        count=count+1
        if count >= limit: break
    except:
        print(name + " ==> Thing")
# Out:
# Canadian ==> people
# India ==> a country
# China ==> a country
# Canadian Pharmacists Association ==> Thing
# Mina Tadrous ==> Thing
# Toronto ==> the provincial capital
# U.S. ==> a country
# Tadrous ==> Thing
# Canada ==> a country
# Queen ==> Thing
# Kingston ==> Thing
# North America ==> a continent
# Kas ==> the brand name
# Duffin ==> a surname
# refillsNew Brunswick ==> an informal name
# Europe ==> a continent
# Yukon ==> the Yukon
# Whitehorse ==> the capital
# Bethany Church ==> Μαρία
# Alaska Highway ==> the contiguous United States
# Elias Dental ==> the inferior dental nerve
# Paul ==> Thing
# Senate ==> a deliberative assembly
# Washington ==> Thing
# Republican ==> Thing
# Senate Majority Leader Mitch ==> an American politician
# McConnell ==> an American politician

# %%
count = 0;
limit = 20;

for name in name_entities_custom:
    try:
        page = wikipedia.page(name)
        sentence = nltk.sent_tokenize(page.summary)[0] 
        grammar = "NP: <VB.?>{<DT>*<JJ.*>*<NN.*>+}"
        cp = nltk.RegexpParser(grammar)
        tokens = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(tokens)
        custom_ne_chunked = cp.parse(tagged)
        print(name + " ==> "+ extract_noun_phrase(custom_ne_chunked))
        count=count+1
        if count >= limit: break
    except:
        print(name + " ==> Thing")
# Out:
# India ==> a country
# China ==> a country
# COVID-19 ==> Thing
# Provincial ==> Thing
# the Canadian ==> a transcontinental passenger train
# Pharmacists ==> health professionals
# Association ==> Thing
# Mina ==> Thing
# Tadrous ==> Thing
# Toronto ==> the provincial capital
# worried Canadians ==> Thing
# the U.S. ==> a country
# Canada ==> a country
# Ongoing ==> Thing
# Dr. ==> an American rapper
# Jacalyn ==> a Canadian medical historian
# Duffin ==> a surname
# Queen ==> Thing
# University ==> an institution
# Kingston ==> Thing
# Ont. ==> Thing
# North ==> Thing
# America ==> a country
# Kas ==> the brand name
# Roussy/CBC ==> achievements
# Brunswick ==> Thing
# outbreak India ==> Thing
# Europe ==> a continent
# Whitehorse ==> the capital
# Thursday ==> the day

# %% [markdown]
# ## Issues during the implementation
# - I was not sure about the Regular Expressions for ntlk parser. I tested different expressions and left the ones, which gave the most retrieval.
# - As I have already noted before, without the use case, determining the proper regular expressions was up to my preferences.

# %% [markdown]
# ## Future work
# - better entity classification that supports at least the first paragraph on Wikipedia
# - data cleansing using stemming and lemmatization to reduce number of found entities (I did not have to deal with this, because my dataset contains a lot of sentences from various number of topics. Thus, named entities do not repeat that much in the selection of 500 sentences)
